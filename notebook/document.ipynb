# %% [markdown]
# ### Data Ingestion

# %%
# Document Structure
from langchain_core.documents import Document

# %%
# Example Document
doc = Document(
    page_content = "This is the dummy content to explore document data strucutre",
    metadata =  {
        "source":"example.txt",
        "pages": 1,
        "author":"John Doe",
        "date_created": "04-03-2026"
    }
) 

print(doc)
# Out:
# page_content='This is the dummy content to explore document data strucutre' metadata={'source': 'example.txt', 'pages': 1, 'author': 'John Doe', 'date_created': '04-03-2026'}

# %%
# Creating txt files using python
import os
os.makedirs("../data/text_files",exist_ok = True)

# %%
sample_texts={
    "../data/text_files/python_intro.txt":"""Python Programming Introduction

Python is a high-level, interpreted programming language known for its simplicity and readability.
Created by Guido van Rossum and first released in 1991, Python has become one of the most popular
programming languages in the world.

Key Features:
- Easy to learn and use
- Extensive standard library
- Cross-platform compatibility
- Strong community support

Python is widely used in web development, data science, artificial intelligence, and automation.""",
    
    "../data/text_files/machine_learning.txt": """Machine Learning Basics

Machine learning is a subset of artificial intelligence that enables systems to learn and improve
from experience without being explicitly programmed. It focuses on developing computer programs
that can access data and use it to learn for themselves.

Types of Machine Learning:
1. Supervised Learning: Learning with labeled data
2. Unsupervised Learning: Finding patterns in unlabeled data
3. Reinforcement Learning: Learning through rewards and penalties

Applications include image recognition, speech processing, and recommendation systems
    
    
    """

}

for filepath,content in sample_texts.items():
    with open(filepath,'w',encoding="utf-8") as f:
        f.write(content)

print("Sample text files created!!")
# Out:
# Sample text files created!!

# %%
# TextLoader -- Only for text files
from langchain_community.document_loaders import TextLoader

loader = TextLoader("../data/text_files/python_intro.txt",encoding="utf-8")
document = loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
# Directory loader text files
from langchain_community.document_loaders import DirectoryLoader

# Loading all text files from the data directory
dir_loader = DirectoryLoader(
    "../data/text_files",
    glob = "**/*.txt", # Pattern to match files
    loader_cls = TextLoader, # Loader class to use
    loader_kwargs = {'encoding':'utf-8'},
    show_progress=False
)

text_documents = dir_loader.load()
text_documents
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\machine_learning.txt'}, page_content='Machine Learning Basics\n\nMachine learning is a subset of artificial intelligence that enables systems to learn and improve\nfrom experience without being explicitly programmed. It focuses on developing computer programs\nthat can access data and use it to learn for themselves.\n\nTypes of Machine Learning:\n1. Supervised Learning: Learning with labeled data\n2. Unsupervised Learning: Finding patterns in unlabeled data\n3. Reinforcement Learning: Learning through rewards and penalties\n\nApplications include image recognition, speech processing, and recommendation systems\n\n\n    '),
#  Document(metadata={'source': '..\\data\\text_files\\python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
# Directory loader for loading all the pdf files
from langchain_community.document_loaders import PyPDFLoader,PyMuPDFLoader

dir_loader = DirectoryLoader(
    "../data/pdf_files",
    glob = "**/*.pdf",
    loader_cls = PyMuPDFLoader,
    show_progress = False
)

pdf_documents = dir_loader.load()
pdf_documents
# Out:
# [Document(metadata={'producer': 'ReportLab PDF Library - www.reportlab.com', 'creator': '(unspecified)', 'creationdate': '2026-03-04T10:02:45+00:00', 'source': '..\\data\\pdf_files\\attention.pdf', 'file_path': '..\\data\\pdf_files\\attention.pdf', 'total_pages': 1, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-03-04T10:02:45+00:00', 'trapped': '', 'modDate': "D:20260304100245+00'00'", 'creationDate': "D:20260304100245+00'00'", 'page': 0}, page_content='Attention Mechanism (Dummy Content)\nAttention is a technique used in deep learning that allows models to focus on specific parts of input\ndata. It is widely used in Natural Language Processing and Transformer architectures.\nKey Ideas: - Assign importance scores to different tokens - Improve context understanding - Used in\nmodels like Transformers\nThis PDF is generated only for practice with directory loaders in LangChain.'),
#  Document(metadata={'producer': 'ReportLab PDF Library - www.reportlab.com', 'creator': '(unspecified)', 'creationdate': '2026-03-04T10:02:45+00:00', 'source': '..\\data\\pdf_files\\embeddings.pdf', 'file_path': '..\\data\\pdf_files\\embeddings.pdf', 'total_pages': 1, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-03-04T10:02:45+00:00', 'trapped': '', 'modDate': "D:20260304100245+00'00'", 'creationDate': "D:20260304100245+00'00'", 'page': 0}, page_content='Embeddings (Dummy Content)\nEmbeddings are numerical vector representations of data such as text, images, or audio. They capture\nsemantic meaning so that similar items are close in vector space.\nCommon Uses: - Semantic search - Recommendation systems - Retrieval Augmented Generation\n(RAG)\nThis is dummy content for practicing document loading.'),
#  Document(metadata={'producer': 'ReportLab PDF Library - www.reportlab.com', 'creator': '(unspecified)', 'creationdate': '2026-03-04T10:02:45+00:00', 'source': '..\\data\\pdf_files\\objectdetection.pdf', 'file_path': '..\\data\\pdf_files\\objectdetection.pdf', 'total_pages': 1, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-03-04T10:02:45+00:00', 'trapped': '', 'modDate': "D:20260304100245+00'00'", 'creationDate': "D:20260304100245+00'00'", 'page': 0}, page_content='Object Detection (Dummy Content)\nObject detection is a computer vision task that identifies objects in images and locates them using\nbounding boxes.\nPopular Models: - YOLO - Faster R-CNN - SSD\nApplications: - Autonomous driving - Security systems - Retail analytics\nThis file exists only for practice with document loaders.'),
#  Document(metadata={'producer': 'ReportLab PDF Library - www.reportlab.com', 'creator': '(unspecified)', 'creationdate': '2026-03-04T10:02:45+00:00', 'source': '..\\data\\pdf_files\\proposal.pdf', 'file_path': '..\\data\\pdf_files\\proposal.pdf', 'total_pages': 1, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-03-04T10:02:45+00:00', 'trapped': '', 'modDate': "D:20260304100245+00'00'", 'creationDate': "D:20260304100245+00'00'", 'page': 0}, page_content='Project Proposal (Dummy Content)\nTitle: Sample AI Research Proposal\nObjective: To explore machine learning techniques for information retrieval and document\nunderstanding.\nScope: - Data collection - Model training - Evaluation\nExpected Outcome: A prototype system demonstrating retrieval augmented generation.\nThis document is a placeholder for practice purposes.')]

# %%
# Checking the type
type(pdf_documents[0])
# Out:
# langchain_core.documents.base.Document
